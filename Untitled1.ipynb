# %%
from pymongo import MongoClient

# %%
connect_str = "mongodb+srv://michaelcornelis:MongoDB123@cluster0.gxbh0ig.mongodb.net/test"

# %%
client = MongoClient(connect_str)

# %%
client
# Out:
# MongoClient(host=['ac-kfoi6hq-shard-00-02.gxbh0ig.mongodb.net:27017', 'ac-kfoi6hq-shard-00-00.gxbh0ig.mongodb.net:27017', 'ac-kfoi6hq-shard-00-01.gxbh0ig.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-dt6uit-shard-0', tls=True)

# %%
client.list_database_names()
# Out:
# ['import_export_db',
#  'sample_mflix',
#  'sample_training',
#  'test_db',
#  'admin',
#  'local']

# %%
sample_mflix = client.sample_mflix

# %%
sample_mflix
# Out:
# Database(MongoClient(host=['ac-kfoi6hq-shard-00-02.gxbh0ig.mongodb.net:27017', 'ac-kfoi6hq-shard-00-00.gxbh0ig.mongodb.net:27017', 'ac-kfoi6hq-shard-00-01.gxbh0ig.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-dt6uit-shard-0', tls=True), 'sample_mflix')

# %%
sample_mflix.list_collection_names()
# Out:
# ['theaters', 'comments', 'movies', 'sessions', 'users']

# %%
sample_mflix.comments.find_one()
# Out:
# {'_id': ObjectId('5a9427648b0beebeb69579e7'),
#  'name': 'Mercedes Tyler',
#  'email': 'mercedes_tyler@fakegmail.com',
#  'movie_id': ObjectId('573a1390f29313caabcd4323'),
#  'text': 'Eius veritatis vero facilis quaerat fuga temporibus. Praesentium expedita sequi repellat id. Corporis minima enim ex. Provident fugit nisi dignissimos nulla nam ipsum aliquam.',
#  'date': datetime.datetime(2002, 8, 18, 4, 56, 7)}

# %%
sample_mflix.comments.find()

# %%
for i in sample_mflix.comments.find():
    print(i)
# Out:
# {'_id': ObjectId('5a9427648b0beebeb69579e7'), 'name': 'Mercedes Tyler', 'email': 'mercedes_tyler@fakegmail.com', 'movie_id': ObjectId('573a1390f29313caabcd4323'), 'text': 'Eius veritatis vero facilis quaerat fuga temporibus. Praesentium expedita sequi repellat id. Corporis minima enim ex. Provident fugit nisi dignissimos nulla nam ipsum aliquam.', 'date': datetime.datetime(2002, 8, 18, 4, 56, 7)}
# {'_id': ObjectId('5a9427648b0beebeb69579f5'), 'name': 'John Bishop', 'email': 'john_bishop@fakegmail.com', 'movie_id': ObjectId('573a1390f29313caabcd446f'), 'text': 'Id error ab at molestias dolorum incidunt. Non deserunt praesentium dolorem nihil. Optio tempora vel ut quas.\nMinus dicta numquam quasi. Rem totam cumque at eum. Ullam hic ut ea magni.', 'date': datetime.datetime(1975, 1, 21, 0, 31, 22)}
# ...

# %%
import pprint

# %%
for i in sample_mflix.comments.find():
    pprint.pprint(i)
# Out:
# {'_id': ObjectId('5a9427648b0beebeb69579e7'),
#  'date': datetime.datetime(2002, 8, 18, 4, 56, 7),
#  'email': 'mercedes_tyler@fakegmail.com',
#  'movie_id': ObjectId('573a1390f29313caabcd4323'),
#  'name': 'Mercedes Tyler',
#  'text': 'Eius veritatis vero facilis quaerat fuga temporibus. Praesentium '
#          'expedita sequi repellat id. Corporis minima enim ex. Provident fugit '
#          'nisi dignissimos nulla nam ipsum aliquam.'}
# {'_id': ObjectId('5a9427648b0beebeb69579f5'),
#  'date': datetime.datetime(1975, 1, 21, 0, 31, 22),
#  'email': 'john_bishop@fakegmail.com',
#  'movie_id': ObjectId('573a1390f29313caabcd446f'),
#  'name': 'John Bishop',
#  'text': 'Id error ab at molestias dolorum incidunt. Non deserunt praesentium '
#          'dolorem nihil. Optio tempora vel ut quas.\n'
#          'Minus dicta numquam quasi. Rem totam cumque at eum. Ullam hic ut ea '
#          'magni.'}
# {'_id': ObjectId('5a9427648b0beebeb6957a21'),
# ...

# %%
client.test_pymongo_db
# Out:
# Database(MongoClient(host=['ac-kfoi6hq-shard-00-02.gxbh0ig.mongodb.net:27017', 'ac-kfoi6hq-shard-00-00.gxbh0ig.mongodb.net:27017', 'ac-kfoi6hq-shard-00-01.gxbh0ig.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-dt6uit-shard-0', tls=True), 'test_pymongo_db')

# %%
test_pymongo_db = client.test_pymongo_db

# %%
test_pymongo_db.py_collection.insert_many([{"test":1}])

# %%
test_pymongo_db.find.one()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 test_pymongo_db.find.one()
#
# File /opt/homebrew/lib/python3.11/site-packages/pymongo/collection.py:3223, in Collection.__call__(self, *args, **kwargs)
#    3216 if "." not in self.__name:
#    3217     raise TypeError(
#    3218         "'Collection' object is not callable. If you "
#    3219         "meant to call the '%s' method on a 'Database' "
#    3220         "object it is failing because no such method "
#    3221         "exists." % self.__name
#    3222     )
# -> 3223 raise TypeError(
#    3224     "'Collection' object is not callable. If you meant to "
#    3225     "call the '%s' method on a 'Collection' object it is "
#    3226     "failing because no such method exists." % self.__name.split(".")[-1]
#    3227 )
#
# ...

# %%
test_pymongo_db.find()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 test_pymongo_db.find()
#
# File /opt/homebrew/lib/python3.11/site-packages/pymongo/collection.py:3217, in Collection.__call__(self, *args, **kwargs)
#    3215 """This is only here so that some API misusages are easier to debug."""
#    3216 if "." not in self.__name:
# -> 3217     raise TypeError(
#    3218         "'Collection' object is not callable. If you "
#    3219         "meant to call the '%s' method on a 'Database' "
#    3220         "object it is failing because no such method "
#    3221         "exists." % self.__name
#    3222     )
#    3223 raise TypeError(
#    3224     "'Collection' object is not callable. If you meant to "
#    3225     "call the '%s' method on a 'Collection' object it is "
#    3226     "failing because no such method exists." % self.__name.split(".")[-1]
# ...

# %%
test_pymongo_db.py.collection.find.one()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 test_pymongo_db.py.collection.find.one()
#
# AttributeError: 'function' object has no attribute 'one'

# %%
test_pymongo_db.py_collection.find.one()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 test_pymongo_db.py_collection.find.one()
#
# AttributeError: 'function' object has no attribute 'one'

# %%
test_pymongo_db.py_collection.find_one()
# Out:
# {'_id': ObjectId('649428ce71b8b88c75f3b58e'), 'test': 1}

# %%
test_pymongo_db.py

# %%
movies = sample_mflix.movies

# %%
moviesz
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 moviesz
#
# NameError: name 'moviesz' is not defined

# %%
movies
# Out:
# Collection(Database(MongoClient(host=['ac-kfoi6hq-shard-00-02.gxbh0ig.mongodb.net:27017', 'ac-kfoi6hq-shard-00-00.gxbh0ig.mongodb.net:27017', 'ac-kfoi6hq-shard-00-01.gxbh0ig.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-dt6uit-shard-0', tls=True), 'sample_mflix'), 'movies')

# %%
movies.find_one()
# Out:
# {'_id': ObjectId('573a1390f29313caabcd4135'),
#  'plot': 'Three men hammer on an anvil and pass a bottle of beer around.',
#  'genres': ['Short'],
#  'runtime': 1,
#  'cast': ['Charles Kayser', 'John Ott'],
#  'num_mflix_comments': 0,
#  'title': 'Blacksmith Scene',
#  'fullplot': 'A stationary camera looks at a large anvil with a blacksmith behind it and one on either side. The smith in the middle draws a heated metal rod from the fire, places it on the anvil, and all three begin a rhythmic hammering. After several blows, the metal goes back in the fire. One smith pulls out a bottle of beer, and they each take a swig. Then, out comes the glowing metal and the hammering resumes.',
#  'countries': ['USA'],
#  'released': datetime.datetime(1893, 5, 9, 0, 0),
#  'directors': ['William K.L. Dickson'],
#  'rated': 'UNRATED',
#  'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  'lastupdated': '2015-08-26 00:03:50.133000000',
#  'year': 1893,
# ...

# %%
movies.aggregate([{"$sortByCount": "$year"}])

# %%
aggr = movies.aggregate([{"$sortByCount": "$year"}])

# %%
pprint.pprint(aggr)

# %%
for i in aggr:
    pprint.pprint(i)
# Out:
# {'_id': 2014, 'count': 1147}
# {'_id': 2012, 'count': 1109}
# {'_id': 2011, 'count': 1040}
# {'_id': 2009, 'count': 990}
# {'_id': 2010, 'count': 970}
# {'_id': 2008, 'count': 969}
# {'_id': 2007, 'count': 871}
# {'_id': 2006, 'count': 844}
# {'_id': 2005, 'count': 758}
# {'_id': 2004, 'count': 741}
# {'_id': 2003, 'count': 656}
# {'_id': 2002, 'count': 655}
# {'_id': 2001, 'count': 645}
# {'_id': 2000, 'count': 618}
# {'_id': 1998, 'count': 552}
# {'_id': 1999, 'count': 542}
# {'_id': 2015, 'count': 485}
# {'_id': 1997, 'count': 458}
# {'_id': 1996, 'count': 431}
# {'_id': 1995, 'count': 396}
# {'_id': 1994, 'count': 318}
# {'_id': 1993, 'count': 292}
# {'_id': 1992, 'count': 288}
# {'_id': 1988, 'count': 265}
# {'_id': 1991, 'count': 252}
# {'_id': 1989, 'count': 244}
# {'_id': 1990, 'count': 244}
# {'_id': 1987, 'count': 239}
# {'_id': 1984, 'count': 211}
# {'_id': 1986, 'count': 206}
# {'_id': 1985, 'count': 204}
# {'_id': 1982, 'count': 185}
# {'_id': 1981, 'count': 179}
# ...
